# %%
# !pip install kaggle
# Out:
# ...
# [notice] A new release of pip is available: 25.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import kaggle

# %%
# !kaggle datasets download -d najir0123/walmart-10k-sales-datasets -f Walmart.csv
# Out:
# ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))

# %%
# !kaggle datasets download -d najir0123/walmart-10k-sales-datasets -f Walmart.csv
# Out:
# Dataset URL: https://www.kaggle.com/datasets/najir0123/walmart-10k-sales-datasets
# License(s): MIT
# ...
#   0%|          | 0.00/819k [00:00<?, ?B/s]
# 100%|##########| 819k/819k [00:01<00:00, 466kB/s]
# 100%|##########| 819k/819k [00:01<00:00, 465kB/s]

# %%
import zipfile

zip_ref = zipfile.ZipFile('Walmart.csv.zip') 

zip_ref.extractall() # extract file to dir

zip_ref.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 3
#       1 import zipfile
#       2
# ----> 3 zip_ref = zipfile.ZipFile('Walmart.csv.zip')
#       4
#       5 zip_ref.extractall() # extract file to dir
#       6
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\zipfile\__init__.py:1362, in ZipFile.__init__(self, file, mode, compression, allowZip64, compresslevel, strict_timestamps, metadata_encoding)
#    1360 while True:
#    1361     try:
# -> 1362         self.fp = io.open(file, filemode)
#    1363     except OSError:
#    1364         if filemode in modeDict:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Walmart.csv.zip'

# %%
import os
print(os.listdir())
# Out:
# ['.ipynb_checkpoints', 'Walmart.csv', 'WALMARTSALES ANALSYS.ipynb']

# %%
import pandas as pd
df = pd.read_csv("Walmart.csv")

# %%
df
# Out:
#        invoice_id   Branch         City                category unit_price  \
# 0               1  WALM003  San Antonio       Health and beauty     $74.69
# 1               2  WALM048    Harlingen  Electronic accessories     $15.28
# 2               3  WALM067  Haltom City      Home and lifestyle     $46.33
# 3               4  WALM064      Bedford       Health and beauty     $58.22
# 4               5  WALM013       Irving       Sports and travel     $86.31
# ...           ...      ...          ...                     ...        ...
# 10046        9996  WALM056      Rowlett     Fashion accessories        $37
# 10047        9997  WALM030   Richardson      Home and lifestyle        $58
# 10048        9998  WALM050     Victoria     Fashion accessories        $52
# 10049        9999  WALM032        Tyler      Home and lifestyle        $79
# 10050       10000  WALM069     Rockwall     Fashion accessories        $62
#
# ...

# %%
df.shape
# Out:
# (10051, 11)

# %%
df.head()
# Out:
#    invoice_id   Branch         City                category unit_price  \
# 0           1  WALM003  San Antonio       Health and beauty     $74.69
# 1           2  WALM048    Harlingen  Electronic accessories     $15.28
# 2           3  WALM067  Haltom City      Home and lifestyle     $46.33
# 3           4  WALM064      Bedford       Health and beauty     $58.22
# 4           5  WALM013       Irving       Sports and travel     $86.31
#
#    quantity      date      time payment_method  rating  profit_margin
# 0       7.0  05/01/19  13:08:00        Ewallet     9.1           0.48
# 1       5.0  08/03/19  10:29:00           Cash     9.6           0.48
# 2       7.0  03/03/19  13:23:00    Credit card     7.4           0.33
# 3       8.0  27/01/19  20:33:00        Ewallet     8.4           0.33
# 4       7.0  08/02/19  10:37:00        Ewallet     5.3           0.48

# %%
df.describe()
# Out:
#          invoice_id      quantity        rating  profit_margin
# count  10051.000000  10020.000000  10051.000000   10051.000000
# mean    5025.741220      2.353493      5.825659       0.393791
# std     2901.174372      1.602658      1.763991       0.090669
# min        1.000000      1.000000      3.000000       0.180000
# 25%     2513.500000      1.000000      4.000000       0.330000
# 50%     5026.000000      2.000000      6.000000       0.330000
# 75%     7538.500000      3.000000      7.000000       0.480000
# max    10000.000000     10.000000     10.000000       0.570000

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10051 entries, 0 to 10050
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   invoice_id      10051 non-null  int64
#  1   Branch          10051 non-null  str
#  2   City            10051 non-null  str
#  3   category        10051 non-null  str
#  4   unit_price      10020 non-null  str
#  5   quantity        10020 non-null  float64
#  6   date            10051 non-null  str
#  7   time            10051 non-null  str
#  8   payment_method  10051 non-null  str
#  9   rating          10051 non-null  float64
#  10  profit_margin   10051 non-null  float64
# dtypes: float64(3), int64(1), str(7)
# memory usage: 1.4 MB

# %%
df.duplicated().sum()
# Out:
# np.int64(51)

# %%
df.drop_duplicates(inplace=True)
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.shape
# Out:
# (10000, 11)

# %%
df.isnull().sum()
# Out:
# invoice_id         0
# Branch             0
# City               0
# category           0
# unit_price        31
# quantity          31
# date               0
# time               0
# payment_method     0
# rating             0
# profit_margin      0
# dtype: int64

# %%
df.dropna(inplace=True) #droppping all rows with missing records

# verify
df.isnull().sum() # verify
# Out:
# invoice_id        0
# Branch            0
# City              0
# category          0
# unit_price        0
# quantity          0
# date              0
# time              0
# payment_method    0
# rating            0
# profit_margin     0
# dtype: int64

# %%
df.shape
# Out:
# (9969, 11)

# %%
df.head()
# Out:
#    invoice_id   Branch         City                category unit_price  \
# 0           1  WALM003  San Antonio       Health and beauty     $74.69
# 1           2  WALM048    Harlingen  Electronic accessories     $15.28
# 2           3  WALM067  Haltom City      Home and lifestyle     $46.33
# 3           4  WALM064      Bedford       Health and beauty     $58.22
# 4           5  WALM013       Irving       Sports and travel     $86.31
#
#    quantity      date      time payment_method  rating  profit_margin
# 0       7.0  05/01/19  13:08:00        Ewallet     9.1           0.48
# 1       5.0  08/03/19  10:29:00           Cash     9.6           0.48
# 2       7.0  03/03/19  13:23:00    Credit card     7.4           0.33
# 3       8.0  27/01/19  20:33:00        Ewallet     8.4           0.33
# 4       7.0  08/02/19  10:37:00        Ewallet     5.3           0.48

# %%
df.dtypes
# Out:
# invoice_id          int64
# Branch                str
# City                  str
# category              str
# unit_price            str
# quantity          float64
# date                  str
# time                  str
# payment_method        str
# rating            float64
# profit_margin     float64
# dtype: object

# %%
df['unit_price'] = df['unit_price'].str.replace('$', '').astype(float)

# %%
df.dtypes
# Out:
# invoice_id          int64
# Branch                str
# City                  str
# category              str
# unit_price        float64
# quantity          float64
# date                  str
# time                  str
# payment_method        str
# rating            float64
# profit_margin     float64
# dtype: object

# %%
df.head()
# Out:
#    invoice_id   Branch         City                category  unit_price  \
# 0           1  WALM003  San Antonio       Health and beauty       74.69
# 1           2  WALM048    Harlingen  Electronic accessories       15.28
# 2           3  WALM067  Haltom City      Home and lifestyle       46.33
# 3           4  WALM064      Bedford       Health and beauty       58.22
# 4           5  WALM013       Irving       Sports and travel       86.31
#
#    quantity      date      time payment_method  rating  profit_margin
# 0       7.0  05/01/19  13:08:00        Ewallet     9.1           0.48
# 1       5.0  08/03/19  10:29:00           Cash     9.6           0.48
# 2       7.0  03/03/19  13:23:00    Credit card     7.4           0.33
# 3       8.0  27/01/19  20:33:00        Ewallet     8.4           0.33
# 4       7.0  08/02/19  10:37:00        Ewallet     5.3           0.48

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 9969 entries, 0 to 9999
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   invoice_id      9969 non-null   int64
#  1   Branch          9969 non-null   str
#  2   City            9969 non-null   str
#  3   category        9969 non-null   str
#  4   unit_price      9969 non-null   float64
#  5   quantity        9969 non-null   float64
#  6   date            9969 non-null   str
#  7   time            9969 non-null   str
#  8   payment_method  9969 non-null   str
#  9   rating          9969 non-null   float64
#  10  profit_margin   9969 non-null   float64
# dtypes: float64(4), int64(1), str(6)
# memory usage: 1.5 MB

# %%
df.columns
# Out:
# Index(['invoice_id', 'Branch', 'City', 'category', 'unit_price', 'quantity',
#        'date', 'time', 'payment_method', 'rating', 'profit_margin'],
#       dtype='str')

# %%
df['total Price'] = df['unit_price'] * df['quantity']

# %%
df.head()
# Out:
#    invoice_id   Branch         City                category  unit_price  \
# 0           1  WALM003  San Antonio       Health and beauty       74.69
# 1           2  WALM048    Harlingen  Electronic accessories       15.28
# 2           3  WALM067  Haltom City      Home and lifestyle       46.33
# 3           4  WALM064      Bedford       Health and beauty       58.22
# 4           5  WALM013       Irving       Sports and travel       86.31
#
#    quantity      date      time payment_method  rating  profit_margin  \
# 0       7.0  05/01/19  13:08:00        Ewallet     9.1           0.48
# 1       5.0  08/03/19  10:29:00           Cash     9.6           0.48
# 2       7.0  03/03/19  13:23:00    Credit card     7.4           0.33
# 3       8.0  27/01/19  20:33:00        Ewallet     8.4           0.33
# 4       7.0  08/02/19  10:37:00        Ewallet     5.3           0.48
#
#    total Price
# 0       522.83
# 1        76.40
# 2       324.31
# 3       465.76
# 4       604.17

# %%
df.columns
# Out:
# Index(['invoice_id', 'Branch', 'City', 'category', 'unit_price', 'quantity',
#        'date', 'time', 'payment_method', 'rating', 'profit_margin',
#        'total Price'],
#       dtype='str')

# %%
df.columns = df.columns.str.lower()
df.columns   #Fixing the column name to lower case
# Out:
# Index(['invoice_id', 'branch', 'city', 'category', 'unit_price', 'quantity',
#        'date', 'time', 'payment_method', 'rating', 'profit_margin',
#        'total price'],
#       dtype='str')

# %%
df.shape
# Out:
# (9969, 12)

# %%
df.to_csv('walmart_clean_data.csv', index=False)

# %%
# !pip install pyodbc
# Out:
# ...
# [notice] A new release of pip is available: 25.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pyodbc
print(pyodbc.version)
# Out:
# 5.3.0

# %%
import sqlalchemy as sal

engine = sal.create_engine(
    "mssql+pyodbc://LAPTOP-4L14UMHG\\SQLEXPRESS/master?driver=ODBC+Driver+17+for+SQL+Server"
)

conn = engine.connect()

print("Connected Successfully!")
# Out:
# Connected Successfully!

# %%
df.to_sql(name='walmart', con=engine_mysql, if_exists='append', index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 df.to_sql(name='walmart', con=engine_mysql, if_exists='append', index=False)
#
# NameError: name 'engine_mysql' is not defined

# %%
df.to_sql('walmart', con=conn , index=False, if_exists = 'append')
# Out:
# 51

# %%
df
# Out:
#       invoice_id   branch         city                category  unit_price  \
# 0              1  WALM003  San Antonio       Health and beauty       74.69
# 1              2  WALM048    Harlingen  Electronic accessories       15.28
# 2              3  WALM067  Haltom City      Home and lifestyle       46.33
# 3              4  WALM064      Bedford       Health and beauty       58.22
# 4              5  WALM013       Irving       Sports and travel       86.31
# ...          ...      ...          ...                     ...         ...
# 9995        9996  WALM056      Rowlett     Fashion accessories       37.00
# 9996        9997  WALM030   Richardson      Home and lifestyle       58.00
# 9997        9998  WALM050     Victoria     Fashion accessories       52.00
# 9998        9999  WALM032        Tyler      Home and lifestyle       79.00
# 9999       10000  WALM069     Rockwall     Fashion accessories       62.00
#
# ...

# %%
df.dtypes
# Out:
# invoice_id          int64
# branch                str
# city                  str
# category              str
# unit_price        float64
# quantity          float64
# date                  str
# time                  str
# payment_method        str
# rating            float64
# profit_margin     float64
# total price       float64
# dtype: object
